# %% [markdown]
# # First exersice

# %%
print ("Welcome")
# Out:
# Welcome

# %%
a = 10
b = 5
print (a-b)
# Out:
# 5

# %%
if a > b :
    print ("true")
else : 
    print ("false")
# Out:
# true

# %% [markdown]
# ## Image:

# %% [markdown]
# ![Icon_25radius copy.png](attachment:045160e3-8743-4108-a922-0226cd8f00bb.png)

# %% [markdown]
# ## List:

# %% [markdown]
# #### Groups:
# 1. First
# 2. Second
# 3. third
